# %% [markdown]
# # Mini-projet – Débruitage de maillage 3D
#
# IMI – Optimisation et problèmes inverses
# S8 – 2024/2025
#
# ## Objectif
#
# On cherche à débruiter un maillage triangulé en résolvant le problème :
#
#
# xhat = argmin_(x in {R}^{N**3})
# [||x - z||^2 + lambda R(x)]
#
# où :
# - \( z \) est le maillage bruité
# - \( R(x) \) est une régularisation sur le graphe du maillage
# - \( lambda \) est un paramètre de régularisation

# %% [markdown]
# # Imports

# %%
# ===============================
# Bibliothèques Maths
# ===============================
import numpy as np
import scipy.sparse as sp
import scipy.sparse.linalg as spla

# ===============================
# Processing 3D
# ===============================
import igl  # libigl python binding

# ===============================
# Visualisation
# ===============================
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# ===============================
# IMICPE
# ===============================
import imicpe
import imicpe.optim as optim

print("imicpe version:", imicpe.__version__)
# Out:
# imicpe version: 1.0.15

# %% [markdown]
# # Lecture du maillage

# %%
# Chemin vers le maillage
mesh_path = "sphere.off"

# Lecture
V, F = igl.read_triangle_mesh(mesh_path)

print("Nombre de sommets :", V.shape[0])
print("Nombre de faces :", F.shape[0])
# Out:
# Nombre de sommets : 162
# Nombre de faces : 320

# %% [markdown]
# # Visualisation du maillage

# %%
# def plot_mesh(V, F, title="Mesh"):
#     x, y, z = V[:, 0], V[:, 1], V[:, 2]
#     i, j, k = F[:, 0], F[:, 1], F[:, 2]

#     fig = go.Figure(data=[go.Mesh3d(
#         x=x, y=y, z=z,
#         i=i, j=j, k=k,
#         color='cyan',
#         opacity=0.5
#     )])

#     fig.update_layout(title=title, scene=dict(aspectmode='data'))
#     fig.show()


def plot_mesh(V, F, title="Mesh"):
    """
    V : matrice (n,3) des sommets
    F : matrice (m,3) des faces (indices des sommets)
    """

    x, y, z = V[:, 0], V[:, 1], V[:, 2]
    i, j, k = F[:, 0], F[:, 1], F[:, 2]

    fig = go.Figure()

    # --- Surface avec dégradé ---
    fig.add_trace(go.Mesh3d(
        x=x,
        y=y,
        z=z,
        i=i,
        j=j,
        k=k,
        intensity=z,                 # dégradé basé sur la hauteur
        colorscale='Viridis',        # palette de couleurs
        opacity=0.9,
        showscale=True
    ))

    # --- Construction des arêtes ---
    edges_x = []
    edges_y = []
    edges_z = []

    for tri in F:
        for a, b in [(0, 1), (1, 2), (2, 0)]:
            edges_x += [V[tri[a], 0], V[tri[b], 0], None]
            edges_y += [V[tri[a], 1], V[tri[b], 1], None]
            edges_z += [V[tri[a], 2], V[tri[b], 2], None]

    fig.add_trace(go.Scatter3d(
        x=edges_x,
        y=edges_y,
        z=edges_z,
        mode='lines',
        line=dict(color='black', width=2),
        showlegend=False
    ))

    # --- Mise en page ---
    fig.update_layout(
        title=title,
        scene=dict(aspectmode='data')
    )

    fig.show()

plot_mesh(V, F, "Maillage original")

# %% [markdown]
# # Ajout de bruit Gaussien

# %%
VB = np.zeros((len(V), len(V[0])))
for i in range(len(V)) :
    n = np.random.normal(0, 0.1, len(V[i]))
    xbar = np.array(V[i])
    z = xbar + n
    VB[i] = z

plot_mesh(VB, F, "Maillage bruité")

# %% [markdown]
# # Fonction de coût

# %%
D = optim.generateDiff3D(V, F, 'gradient')
L = optim.generateDiff3D(V, F, 'laplacien')

# attache aux données
def f(x):
    return np.sum((x - VB)**2)

# régularisation
def R(x):
    return np.sum(x**2)

def RD(x):
    return np.sum(D@x**2)

def RL(x):
    return np.sum(L@x**2)

# fonction de coût globale
def E(x,lam):
    return f(x) + lam * RD(x)

# # opérateur proximal de la norme l1
# def prox_l1(x, gamma, lam):
#     return np.sign(x) * np.maximum(np.abs(x) - gamma*lam, 0.0)

# def prox_l2(x, gamma):
#     return x / (1 + 2*gamma)

# def prox_f(x, gamma, lam):
#     """
#     Proximal de f(x) = x^2 + lam |x|
#     """
#     y = prox_l2(x, gamma)
#     return prox_l1(y, gamma, lam)


def prox_tv_mesh(v, D, lam, gamma, n_iter=50):
    """
    Proximal de g(x) = lam * ||D x||_1
    sur maillage 3D
    """
    p = np.zeros_like(D @ v)
    tau = 0.125  # stable en général

    for _ in range(n_iter):
        Dv = D @ (v - gamma * lam * D.T @ p)
        p = p + tau * Dv
        p = p / np.maximum(1, np.abs(p))  # projection L∞

    return v - gamma * lam * D.T @ p

# %% [markdown]
# # Algorithme

# %%
lam = 0.5
tk = 0.01
Niter = 2500

xn_tk = np.zeros(VB.shape)
En_tk = []

xn_tv = np.zeros(VB.shape)
En_tv = []

## boucle Tikhonov ###

for k in range(Niter):
    grad = 2*(xn_tk - VB) + 2*lam*D.T@D@xn_tk
    xn_tk = xn_tk - tk * grad 
    En_tk.append(E(xn_tk, lam))

VF_tk=xn_tk


# ### boucle TV ###

# for k in range(Niter):

#     # étape gradient sur f
#     grad_f = 2*(xn_tv - VB)
#     y = xn_tv - tk * grad_f

#     # étape proximal TV
#     xn_tv = prox_tv_mesh(y, D, lam, tk)

#     En_tv.append(E(xn_tv, lam))

# VF_tv = xn_tv

# %% [markdown]
# # Affichage des résultats

# %%
# Fonction de coût en fonction des itérations
plt_cost_tk = pd.DataFrame({
    'x': np.arange(len(En_tk)),
    'y': En_tk,
    'legend': 'Tikhonov'
})

# plt_cost_tv = pd.DataFrame({
#     'x': np.arange(len(En_tv)),
#     'y': En_tv,
#     'legend': 'TV'
# })


# plt_cost = pd.concat([plt_cost_tk, plt_cost_tv])

# fig = px.line(
#     plt_cost,
#     x='x',
#     y='y',
#     color='legend',   # <-- important
#     log_x=True,
#     log_y=True,
#     labels={
#         'x': 'itérations (logscale)',
#         'y': 'E(x^k) (logscale)',
#         'legend': 'Méthode'
#     },
#     title='Évolution de la fonction de coût en fonction des itérations',
#     width=800,
#     height=350
# )

# fig.show()

# Approximations finales
plot_mesh(VF_tk, F, "Maillage débruité avec Tikhonov")
# plot_mesh(VF_tv, F, "Maillage débruité avec TV")

# %% [markdown]
# **MSE**

# %%
print(VF_tk[0])
print(V[0])

MSE=[]
for i in range (len(V)):
    MSE.append((1/len(V))*np.sum((VF_tk[i]-V[i])**2))

MSE_plt = pd.DataFrame({'x':np.arange(len(MSE)), 'y':MSE, 'legend':'cost'}) 
fig = px.line(MSE_plt, x='x', y='y', log_x=False, log_y=False, labels={'x':'sommets','y':'erreur quadratique moyenne'}, title='MSE', width=800, height=350) 
fig.show()
# Out:
# [0.70661867 0.51062276 0.02965387]
# [0.850651 0.525731 0.      ]
